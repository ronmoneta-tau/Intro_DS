# %% [markdown]
# # <div dir=rtl> תרגול שישי - GLM & Logistic Regression </div>

# %% [markdown]
# <div dir=rtl>
# בתרגול הקודם ביצענו רגרסיה כדי ללמוד לחזות משתנה מטרה רציף. עתה נכליל, ונלמד על משפחה של מודלים ונשתמש באחד מהם כדי לחזות משתנה מטרה בדיד (קטגורי או פשוט בוליאני) -  נבצע סיווג\קלסיפיקציה.
# </div>

# %% [markdown]
# ## <div dir=rtl>GLM</div>

# %% [markdown]
# <div dir=rtl>
# נזכיר כי כאשר ביצענו רגרסיה לינארית, המודל שלנו היה
#
# \begin{align}
# Y=Xβ+\epsilon \\
# \epsilon∼N(0,Σ)
# \end{align}
#
# כאשר **מניחים** שאפסילון הינו איבר רעש המתפלג נורמלית עם ממוצע אפס ומטריצת קו-ווראינס מסוימת סיגמא.
#
# כך, גם y יהיה משתנה מקרי בעל התפלגות נורמאלית (רב מימדית)
# \begin{align}
# Y∼N(Xβ,Σ)
# \end{align}
#
#
# נשים לב כי בעצם בעצם תתקיים לנו הסתברות מותנת של אותו הy בהינתן הx:
# \begin{align}
# p(Y|X) = N(\phi_\beta(X), \Sigma)\ \ Where \ \ \phi_\beta(X) = X^T\beta
# \end{align}
#
# כאשר המשמעות היא **ההסתברות** לראות את התוצאה y עבור וקטור הפיצ'רים x ווקטור הפרמטרים בטא. במקרה הזה ההתפלגות היא כאמור מונחת להיות נורמאלית
#
# <br>
# אבל מה אם המידע שלנו לא מתפלג נורמאלית?
# האם דאטא של תוצאות הטלת מטבע מתפלג נורמאלית? של תפוצה של מגפה? של מקרי שוד בשכונה?
# <br><br>
# </div>

# %% [markdown]
# <div dir=rtl>
# אם כך - נכליל ונדבר על GLM - Generalized Linear Models
# <br>
# משפחה של מודלים לינאריים המותאמת לעבודה עם סוגי דאטא שונים (בעלי התפלגויות שונות)
# <br>
# לכל "סוג" מודל במשפחה יהיו שלושה מרכיבים עיקריים:
# <br><br>
# - Distribution family
# <br>
# - Linear predictor
# <br>
# - Link Function
# </div>

# %% [markdown]
# ## <div dir=rtl>Distribution Family</div>

# %% [markdown]
# <div dir=rtl>
# אם עבור רגרסיה לינארית הנחנו שהמידע שלנו מתפלג נורמאלית , נוכל להניח שיש מקרים בהן הוא מתפלג אחרת!
# <br>
# סוגי מידע שונים יתפלגו בצורה שונה - נורמאלי, פואסון, ברנולי, בינומי ועוד ועוד. לכל סוג התפלגות שונה נתאים מודל (לינארי) קצת שונה
# </div>

# %% [markdown]
# ## <div dir=rtl>Linear Predictor</div>

# %% [markdown]
# <div dir=rtl>
# .החלק שמבצע את התחזית הלינארית
# עבור רגרסיה לינארית היה
# <br>
#
# \begin{align}
# \phi(x) = x^T\beta
# \end{align}
#
# </div>

# %% [markdown]
# ## <div dir=rtl>Link Function</div>

# %% [markdown]
# <div dir=rtl>
# השינוי העיקרי שבעצם מאפשר לנו להכליל את המודל הלינארי שראינו עד כה עבור התפלגויות שונות.
# <br>
# פונקציה זו, g , היא הפונקציה שאחראית לחבר בין הסקאלה הלינארית שקיבלנו בסעיף הקודם לבין הסקאלה של ההתפלגות הרצויה.
# <br>
# במילים אחרות - g ממפה  בין הlinear predictor לבין ה mean (μ) של ההתפלגות של הדאטא.
# </div>
#
# \begin{align}
# g(\mu) = \phi(x)
# \\
# \mu = g^-1(\phi(x))
# \end{align}
#
# <div dir=rtl>
# מה אם כך היה הη שלנו ברגרסיה לינארית?
# <br>
# פונקציית הזהות!
# <br><br>
# מוזמנים לקרוא על הפונקציות השונות עבור ההתפלגויות השונות
# https://en.wikipedia.org/wiki/Generalized_linear_model#Link_function
# </div>

# %% [markdown]
# ## <div dir=rtl>Logistic Regression</div>

# %% [markdown]
# <div dir=rtl>
# עתה נכיר מודל נוסף במשפחת הGLM המשמש בעיקר לקליסיפיקציה-
#
# **Logistic Regression**
# <br>
# Distribution Family: ברנולי
# <br>
# Link Function: logit/sigmoid
# </div>

# %% [markdown]
# <div dir=rtl>
# ניזכר כי מה שאנחנו מחפשים כל הזמן זה את הפרמטרים המתאימים ביותר לפי קריטריון שקבענו (במקרה שלנו - MLE).
# <br>
# נשתמש בידע שלנו על ההתפלגות, ונפתח את הנוסחא.
# <br>
# אז בואו נניח שיש לנו סדרת דגימות שאנחנו יודעים שמתפלגת ברנולי.
# </div>
#
# \begin{align}
# y_1,...,y_m
# \\ y_i ∼ B(p)
# \end{align}
#
# <div dir=rtl>
# נשתמש בשיטת MLE
# </div>

# %% [markdown]
# ### <div dir=rtl>תזכורת - Maximum Likelihood Estimator</div>

# %% [markdown]
# <div dir=rtl>
# נזכיר כי עבור משתנה מקרי X בעל הסתברות P כלשהי ופונקציית צפיפות f התלויה בפרמטר θ פונקציית הlikelihood תוגדר להיות
# </div>
#
# \begin{align}
# L(\theta|x):=f(x|\theta) \ \ Where \ \ \theta \in \Theta, \Theta=\{\mu, \sigma^2\}
# \end{align}
#
# <div dir=rtl>
# במילים אחרות, הפונקצייה משערכת לי "מה הסיכוי" שבהינתן x אני אקבל סט פרמטרים מסוים.
# <br><br>
# כך, הגדרנו גם את המשערך Maximum Likelihood Estimator (MLE) עבור θ:
# <br>
# בהינתן L פונקציית likelihood של איזושהו התפלגות P המוגדרת על פי θ כלשהי וX מתוך ההתפלגות הזו - נגדיר:
# </div>
#
# \begin{align}
# \theta \in \Theta, X ∼ P(\theta) \\
# \hat{\theta}^{\mathrm{MLE}}:=argmax_{\theta \in \Theta} L(\theta|X)
# \end{align}

# %% [markdown]
# **Example** - Let's derive the mean ($\mu$) of a univariate Gaussian distribution with known standard deviation ($\sigma$).
#
# The probability density function of a Gaussian distribution is:
#
# \begin{align}
# [
# f(x|\mu,\sigma) = \frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{(x-\mu)^2}{2\sigma^2}}
# ]
# \end{align}
#
# For a sample of n independent observations, the likelihood function is:
#
# \begin{align}
# [
# L(\mu|x_1,...,x_n) = \prod_{i=1}^n \frac{1}{\sigma\sqrt{2\pi}} e^{-\frac{(x_i-\mu)^2}{2\sigma^2}}
# ]
# \end{align}
#
# Taking the natural logarithm (log-likelihood **):
#
# \begin{align}
# [
# \ell(\mu) = \ln L = -\frac{n}{2}\ln(2\pi) - n\ln(\sigma) - \sum_{i=1}^n \frac{(x_i-\mu)^2}{2\sigma^2}
# ]
# \end{align}
#
# To find the maximum likelihood estimate, we take the derivative with respect to $\mu$ and set it equal to zero:
#
# \begin{align}
# [
# \frac{\partial \ell}{\partial \mu} = \sum_{i=1}^n \frac{(x_i-\mu)}{\sigma^2} = 0
# ]
# \end{align}
#
# Solving for $\mu$:
#
# \begin{align}
# [
# \sum_{i=1}^n (x_i-\mu) = 0
# ]
# \end{align}
#
# \begin{align}
# [
# \sum_{i=1}^n x_i - n\mu = 0
# ]
# \end{align}
#
# \begin{align}
# [
# \mu = \frac{1}{n}\sum_{i=1}^n x_i
# ]
# \end{align}
#
# Therefore, the maximum likelihood estimate for the mean of a Gaussian distribution is the sample mean:
# \begin{align}
# [
# \hat{\mu}_{MLE} = \bar{x} = \frac{1}{n}\sum_{i=1}^n x_i
# ]
# \end{align}
#
# <br>
# **
# Since the logarithm function is a monotonous increasing transformation, the maximizer of the likelihood function is also the maximizer of the log-likelihood.
#
# ***

# %% [markdown]
# <div dir=rtl>
# נחזור עכשיו לבעיה שלנו, וננסה לשערך את θ באמצעות MLE עבור הגדרת הבעיה שהייתה לנו (ברנולי)
# </div>
#
# \begin{align}
# L(\theta|y_1,...y_m)=\Pi{p^{y_i}(1-p)^{1-y_i}}
# \\
# apply \  log \ on \ L(\theta|y_1,...y_m)
# \\
# log-likelihood = \Sigma{y_ilog(p)+(1-y_i)log(1-p)}
# \end{align}
#
# <div dir=rtl>
# <br>
# נותר אם כך רק להציב את הlink function ולפתור
# </div>

# %% [markdown]
# <div dir=rtl>
# כפי שציינו למעלה, בlogistic regression אנו משתמשים בפונקציית הlogit ופונקציית הסיגמואיד ההופכית לה (שגם ראינו בתרגול הקודם)
# </div>
#
# \begin{align}
# logit: \ log(\frac{p}{1-p})=\eta=\sigma^{-1}(\eta) \, \ (0,1) \rightarrow (-\infty,+\infty)
# \\
#
# sigmoid: \ \sigma=\frac{e^\eta}{1+e^\eta} = \frac{1}{1+e^{-\eta}} \, \ (-\infty,+\infty) \rightarrow (0,1)
# \end{align}
#
# <div dir=rtl>
# ובסימונים שהראנו מקודם: <br>
# </div>
#
# \begin{align}
# g=logit: \ logit(p) = \phi(x)=X\beta
#
# \\
# p = g^-1(\phi(x)) = \sigma(\phi(x))
# \end{align}
#
# <div dir=rtl>
# נשים לב כי סיגמואיד מוגדרת בתחום [0,1] והערך המתקבל הוא ההסתברות "להיות" במחלקה כלשהי (קלסיפיקציה - נראה דוגמא בהמשך)
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
# define and plot the logit and the sigmoid functions
# Define logit function
logit = np.log(x/(1-x))

# Define sigmoid function 
sigmoid = 1 / (1 + np.exp(-x))

# Create figure with two subplots
plt.figure(figsize=(15,5))

# Plot logit function
plt.subplot(1,2,1)
plt.plot(x[1:-1], logit[1:-1]) # Exclude endpoints due to division by 0
plt.grid(True)
plt.title('Logit Function')
plt.xlabel('x')
plt.ylabel('logit(x)')

# Plot sigmoid function
plt.subplot(1,2,2)
plt.plot(x, sigmoid)
plt.grid(True)
plt.title('Sigmoid Function')
plt.xlabel('x')
plt.ylabel('σ(x)')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\ronmo\AppData\Local\Temp\ipykernel_17268\1361880580.py:7: RuntimeWarning: invalid value encountered in log
#   logit = np.log(x/(1-x))

# %% [markdown]
# <div dir=rtl>
# recap קצר - אנחנו מחפשים את סט הפרמטרים  (שהוא במקרה שלנו beta) המתאימים ביותר לייצר את הy (בעצם p) הללו בהינתן הxים שקיבלנו.
# <br>
# נעדכן את ההנחות שלנו עם שימוש בlink function -
# <br>
# אנו מניחים כי
# </div>
#
# \begin{align}
# y_i ∼ B(\eta(\phi(x))) = B(\sigma(x_i^T\beta))
# \end{align}
#
# <div dir=rtl>
# ובשביל למצוא את הפרמטרים נציב חזרה בMLE (וניזכר שאנחנו בבעיה בינארית), נגזור ונשווה ל0
# </div>
#
# \begin{align}
# log-likelihood = \Sigma{y_ilog(p)+(1-y_i)log(1-p)} =\\ \Sigma{y_ilog(\frac{e^{x_i^T\beta}}{1+e^{x_i^T\beta}})+(1-y_i)log(1-\frac{e^{x_i^T\beta}}{1+e^{x_i^T\beta}})} =\\ \Sigma^m_{i=1}{y_i*x_i^T\beta-log(1+e^{x_i^T\beta})}
# \end{align}
#
# <div dir=rtl>
# אך איזה באסה - אין פתרון סגור לבעיה הזאת
# מה נוכל לעשות?
# </div>

# %% [markdown]
# ## <div dir=rtl>Gradient Descent</div>

# %% [markdown]
# <div dir=rtl>
# אלגוריתם אופטימיזציה איטרטיבי - יותר בהרצאה
# <br>
# האלגוריתם בכלליות:
# </div>
#
# For a function F(θ) we want to minimize:
# <br>
# (1) Pick a value for θ
# <br>
# (2) While (|F'(θ)| > small value)
# <br>
#                      θ = θ - ηF'(θ)
# <br>
# (Where η is the learning rate)

# %% [markdown]
# ## <div dir=rtl>Prediction</div>
# <div dir=rtl>
#     אוקיי אז נניח שמצאנו את בטא ומזה קיבלנו את פונקציית הסיגמואיד הספציפית (שבה הyים הם הסתברות) - אבל מה עכשיו? <br>
#     כפי שציינו, אנחנו נמצאים בעולם של קליספיקציה - רוצים לחלק את הדגימה למחלקה מסוימת. <br>
#     איך נעשה זאת? קביעת סף! (מישור מפריד) <br>
#     נבחר סף α כלשהו בין 0ל1, כאשר כל מה שמתחתיו יהיה מחלקה מסוימת, וכל מה שמעליו יהיה מחלקה אחרת.<br>
# </div>

# %% [markdown]
# <div dir=rtl>
#      נשים לב שבפועל זה אומר לפתור את המשוואה שתיתן לנו נקודה בודדת
# </div>
#
# \begin{align}
# \sigma(x\beta)=\alpha \ \Rightarrow \ x\beta=logit(\alpha) \ \Rightarrow \ x=\frac{logit(\alpha)}{\beta}
# \end{align}
#
# <div dir=rtl>
#  (מה זה יקרה במקרה הרבה מימדי? רמז - בדר"כ משתמשים בα=0.5)
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

def sigmoid(z):
    """Compute the sigmoid function."""
    return 1 / (1 + np.exp(-z))

theta0 = -6         # intercept
theta1 = 0.15       # coefficient
alpha = 0.85         # decision threshold #TODO: look how the data points shape changes as you change alpha!

exam_scores = np.array([30, 35, 50, 60, 90])
students = ["A", "B", "C", "D", "E"]

# Compute linear combination and probabilities for the synthetic data
z = theta0 + theta1 * exam_scores
probabilities = sigmoid(z)
predicted_classes = (probabilities >= alpha).astype(int)

# Generate values for a smooth sigmoid curve over a range of exam scores
x_values = np.linspace(0, 100, 400)
z_values = theta0 + theta1 * x_values
y_values = sigmoid(z_values)

plt.figure(figsize=(10, 6))

# Plot the sigmoid curve
plt.plot(x_values, y_values, label='Sigmoid Curve', color='blue')

plt.axhline(y=alpha, color='red', linestyle='dashed', label=f'Threshold (alpha={alpha})')

for i, score in enumerate(exam_scores):
    if predicted_classes[i] == 1:
        marker = 's'   # square for class 1
        color = 'green'
    else:
        marker = 'o'   # circle for class 0
        color = 'black'
    plt.scatter(score, probabilities[i], marker=marker, color=color, s=100, edgecolors='k')
    plt.text(score, probabilities[i] + 0.03, f'{students[i]}', ha='center', fontsize=12)

plt.xlabel('Exam Score')
plt.ylabel('Predicted Probability')
plt.title('Logistic Regression Visual Example')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## <div dir=rtl>שאלה 1</div>
#
# <div dir=rtl>
#     בשנת 2008 פרסם הNIH האמריקאי מידע על אודות 4238 תושבי העיר פארמינגהם במדינת מסצ'וסטס. <br />
#     המידע כלל נתונים על בריאותם של המשתתפים במחקר והאם בתוך עשור המשתתפים זוהו כסובלים ממחלות בכלי הדם הכליליים בלב. המידע זמין בקובץ 6_heart_disease_2.csv. <br />
# </div>
# <div dir=rtl style='background-color: #fcf2f2;'>
#     הערה: הדאטאסט אמיתי וניתן להורדה בצורה חופשית. הנתונים בו שונו לצורך הדוגמה. <br />
# </div><br />
# <div dir=rtl>
#     א. טענו את הקובץ לאובייקט מסוג DataFrame.
# </div>

# %%
# %pip install numpy pandas matplotlib seaborn scikit-learn statsmodels
# Out:
# Requirement already satisfied: numpy in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (1.24.4)
# Requirement already satisfied: pandas in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (3.10.1)
# Requirement already satisfied: seaborn in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: scikit-learn in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (1.1.1)
# Requirement already satisfied: statsmodels in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.8.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\ronmo\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.read_csv('6_heart_disease_2.csv')
df.sample(5)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 3841     0   52        2.0              0         0.0     0.0
# 3089     1   54        2.0              0         0.0     0.0
# 1037     1   48        1.0              0         0.0     0.0
# 3230     1   58        2.0              1         3.0     0.0
# 1106     1   53        2.0              1         9.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3841                0             0         0    209.0  111.0   79.0  23.63
# 3089                0             1         0    165.0  151.0  100.0  23.74
# 1037                0             0         0    270.0  131.0   88.0  27.13
# 3230                0             0         0    187.0  136.5   84.0  25.08
# 1106                0             1         0    230.0  137.0   99.0  25.77
#
#       heartRate  glucose  TenYearCHD
# 3841       96.0     70.0           0
# 3089       92.0      NaN           0
# 1037       63.0     55.0           0
# 3230       63.0     68.0           0
# 1106       83.0     79.0           0

# %%
df.describe().T
# Out:
#                   count        mean        std     min     25%    50%  \
# male             4238.0    0.429212   0.495022    0.00    0.00    0.0
# age              4238.0   49.584946   8.572160   32.00   42.00   49.0
# education        4133.0    1.978950   1.019791    1.00    1.00    2.0
# currentSmoker    4238.0    0.494101   0.500024    0.00    0.00    0.0
# cigsPerDay       4209.0    9.003089  11.920094    0.00    0.00    0.0
# BPMeds           4185.0    0.029630   0.169584    0.00    0.00    0.0
# prevalentStroke  4238.0    0.005899   0.076587    0.00    0.00    0.0
# prevalentHyp     4238.0    0.310524   0.462763    0.00    0.00    0.0
# diabetes         4238.0    0.025720   0.158316    0.00    0.00    0.0
# totChol          4188.0  236.721585  44.590334  107.00  206.00  234.0
# sysBP            4238.0  138.430746  28.790759   83.50  118.00  131.0
# diaBP            4238.0   82.893464  11.910850   48.00   75.00   82.0
# BMI              4219.0   25.802008   4.080111   15.54   23.07   25.4
# heartRate        4237.0   75.878924  12.026596   44.00   68.00   75.0
# glucose          3850.0   81.966753  23.959998   40.00   71.00   78.0
# TenYearCHD       4238.0    0.151958   0.359023    0.00    0.00    0.0
#
#                      75%    max
# male               1.000    1.0
# age               56.000   70.0
# education          3.000    4.0
# currentSmoker      1.000    1.0
# cigsPerDay        20.000   70.0
# BPMeds             0.000    1.0
# prevalentStroke    0.000    1.0
# prevalentHyp       1.000    1.0
# diabetes           0.000    1.0
# totChol          263.000  696.0
# sysBP            153.000  335.0
# diaBP             89.875  142.5
# BMI               28.040   56.8
# heartRate         83.000  143.0
# glucose           87.000  394.0
# TenYearCHD         0.000    1.0

# %% [markdown]
# <div dir=rtl>
#     ב. בטבלאת הנתונים עמודה אחת לקיומה של מחלת לב - TenYearCHD ושש עמודות של משתנים רציפים. <br />
#     עבור כל זוג משתנים רציפים צרו תרשים המתאר את התפלגות הדגימות כתלות בשני המשתנים. על צבע הדגימה לשקף את סוג הדגימה - כלומר האם היא דגימה של אדם אשר לקה במחלת לב כלילית או לא.
# </div>

# %%
continuous = ['totChol','sysBP','diaBP','BMI','heartRate','glucose']

# %%
import seaborn as sns

pairp = sns.pairplot(
    df[continuous + ['TenYearCHD']],
    hue='TenYearCHD',
    plot_kws={'alpha':0.25}
)

# %% [markdown]
# <div dir=rtl>
#     בתרשים למעלה אנחנו רואים את עמודות הפיצ'רים (למשל דופק בעת הגעה לרופא, אינדקס מסת גוף ועוד) אחת כתלות בשנייה.  כאשר כל נקודה היא מקרה מהמדגם (שורה יצת הדאטא). הצבע הוא עמודת המטרה. בכל המשבצות שבשורה מסוימת ציר ה-Y הוא פיצ"ר מסוים, למשל בכל הגרפים בשורה שנייה ציר ה-Y הוא ה- SysBP, ולהפך בכל התמונות בעמודה השנייה, ה- SysBP ציר ה-X
#     <br />באלכסון מוצגות היסטוגרמות של הערכים בחלוקה לעמודת המטרה כאשר ציר X הוא פיצ"ר הרלוונטי למשל ה-SysBP משבצת השנייה באלכסון.<br />
#     <br />
#     ניתן לראות שה-SysBP (ובמידה פחותה ה-diaBP) נותנות הפרדה טובה בין הצבעים כלומר בעלות פוטנציאל לסיווג (חיזוי המטרה) ע"י השוואה לסף בחד מימד או העברת ישר חוצה בדו-מימד
# </div>
# <br />
# ----------------------------------------------------------------------------------------------
# <div dir=rtl>
#     ג. צרו מודל לינארי לניבוי האם נבדק יחלה או לא יחלה על בסיס פצ'ר אחד.
#     <br /><br />
#     נבחר במודל מסוג רגרסיה לוגיסטית.
#     </br>
#      נשים לב לא להתבלבל עם מודל מסוג רגרסיה לינארית המשמש לפרדיקציה של ערכים בתחום הרציף. <br />
#     ברגרסיה לוגיסטית חד-מימדית נשתמש בפונקציה מסוג סיגמואיד ונתאים אותה לדאטא או ליתר דיוק לצפיפות היחסית של הנקודות משתי המחלקות. הסיגמואיד  מחזיר מספר בתחום [0,1]. נהוג להשתמש בערך הזה כהסתברות להיות במחלקה החיובית ואנחנו נסווג דוגמה כשייכת למחלקה החיובית אם ההסתברות הזו גדולה מ0.5.
#     </br>
#     </br>
#      כפי שבמצב החד מימדי קבענו "מישור מפריד" חד מימדי בין המחלקות השונות (סף מספרי) כך נוכל לקבוע ישר עבור המקרה הדו מימדי, מישור מפריד עבור המקרה התלת מימדי וכן הלאה וכן הלאה..
#
# </div>

# %% [markdown]
# %%html <iframe width="560" height="315" src="https://www.youtube.com/embed/smLdMzVlmyU?si=jbBtJqFe3_BH61XB&amp;clip=UgkxLiavyVaCxyxGEYrcl_33I340xpipvfC_&amp;clipt=EL7QHBjJlR4" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
#
# My clip: https://youtube.com/clip/UgkxLiavyVaCxyxGEYrcl_33I340xpipvfC_?si=p8oh21fokYMLdlkq
#
# Full video: https://www.youtube.com/clip/UgkxLiavyVaCxyxGEYrcl_33I340xpipvfC_

# %% [markdown]
# TODO image
#
# <br />
# <div dir=rtl>
#     המשוואות המתארות את המודל מפורטות למטה.
#     </br>
#     עבור המקרה הפרטי בו הפרדיקציה תלויה במשתנה אחד ממורכז סביב אפס עם שיפוע רבע:
# </div>

# %% [markdown]
# \begin{align}
# \hat p(y=1) = \frac{1}{1+e^{-z}}\\
# \end{align}
# <div dir=rtl>
#     במקרה החד מימדי הכללי בו המשתנה הבלתי תלוי הוא x:
#
# \begin{align}
# z = a_0 + a_1x\\
# \end{align}
#
# שני הפרמטרים קובעים את מיקום ואת חדות המעבר מ-0 ל-1
# </br>
#     במקרה הכללי בו הנקודה מיוצגת על ידי ווקטור של משתנים בלתי תלויים X ומקדמים A:
#
# \begin{align}
# z = A^TX\\
# \end{align}
# </div>
# השיפועים הצמודים למשתנים השונים קובעים את הוקטור של ציר ההשתנות ושל משטחי ההפרדה הניצבים לו
# </br>
#  (ובנוסף, את חדות ההפרדה שתגדל אם נכפיל את כל השיפועים באותו מספר)

# %% [markdown]
# <div dir=rtl>
# נשתמש במקרה החד מימדי כדי להדגים איך הפרמטרים למעלה משפיעים על צורת הפונקציה,
# </div>
#
# <div dir=rtl>
#     נתחיל עם המאפיין sysBP - אשר מדווח על לחץ הדם הסיסטולי של המטופל בהגעה למרפאה. <br />
#     נבחר בו משום שבתרשים למעלה ניתן לראות הפרדה טובה של שתי המחלקות לפי המאפיין הזה.
# </div>

# %%
import matplotlib.pyplot as plt
import numpy as np

params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large',
         'axes.grid':True,
         'axes.grid.which':'both'
         }
plt.rcParams.update(params)

plt.subplot(1,2,1)
scatp = df[['sysBP','TenYearCHD']].plot.scatter(
    x='sysBP',
    y='TenYearCHD',
    c='TenYearCHD',
    cmap='jet',
    alpha=0.2,
    sharex=False,
    ax=plt.gca()
)
plt.subplot(1,2,2)
df[['sysBP','TenYearCHD']].plot.box(by='TenYearCHD', ax=plt.gca())
# Out:
# sysBP    Axes(0.547727,0.125;0.352273x0.755)
# dtype: object

# %% [markdown]
# The boxplot is a nice summary already suggesting a threshold around sysBP=150.
#
# Can we visualize the denisty better?

# %%
plt.figure(figsize=(10, 3))

df_ = pd.DataFrame(df[['sysBP','TenYearCHD']])
df_.TenYearCHD = df_.TenYearCHD.astype('float64')  
df_[['TenYearCHD']] += 0.05*np.random.randn(len(df_), 1)

scatp = df_.plot.scatter(
    x='sysBP',
    y='TenYearCHD',
    #c='TenYearCHD',
    #cmap='jet',
    sharex=False, 
    colorbar=False,
    alpha=0.2,
    title='Visualize data density'
)
plt.text(90, 0.4, fontsize=12,
         s='NOTE: added random y-offset of points \nfrom their actual values 0/1 \nto visualize density',
         )

# # ! Crude estimate of probability as bin-wise histograms ratio
# do_density = True  # TODO True ignores unbalanced data - what's the problem with that? (prior probability..)
# h1, bins = np.histogram(df_[df.TenYearCHD==1], range(90, 260, 10), density=do_density)
# h0, bins = np.histogram(df_[df.TenYearCHD==0], range(90, 260, 10), density=do_density)

# plt.plot(bins[1:], h1 / (h0+h1), 'kd-', alpha=0.5)
plt.legend(['data','empiric probability per bin,\n as ratio of histogram to sum'])
plt.xlim(80, 300)
plt.xlabel('SysBP')
# Out:
# c:\Users\ronmo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Text(0.5, 0, 'SysBP')

# %% [markdown]
# <div dir=rtl>
#     כעת ננסה להתאים מודל סיגמואיד של הסתברות (רגרסיה לוגיסטית) .
#     </br>
# </div>

# %%
import statsmodels.api as sm

df.sort_values(by='sysBP', inplace=True)
x = df['sysBP']
X = sm.add_constant(x)
Y = df['TenYearCHD']

logistic_1d = sm.Logit(Y, X)
results = logistic_1d.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.209686
#          Iterations 8
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             TenYearCHD   No. Observations:                 4238
# Model:                          Logit   Df Residuals:                     4236
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 20 Apr 2025   Pseudo R-squ.:                  0.5079
# Time:                        22:15:10   Log-Likelihood:                -888.65
# converged:                       True   LL-Null:                       -1805.8
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -14.5705      0.490    -29.761      0.000     -15.530     -13.611
# sysBP          0.0835      0.003     27.845      0.000       0.078       0.089
# ==============================================================================
# """

# %% [markdown]
# <div dir=rtl>
#     גם כאן, כמו ברגרסיה לינארית, אנחנו מקבלים מקדמים המתאימים למקדם החופשי ולמשתנה לפיו ביצענו את הרגרסיה.
#     <br />
#     ננסה להבין את המשמעות של מה שקיבלנו. לצורך כך נשרטט את הפונקציה שקיבלנו יחד עם הנקודות המקוריות
# </div>

# %%
plt.figure(figsize=(20, 6))
# Create a copy and add noise:
df_ = pd.DataFrame(df[['sysBP','TenYearCHD']])
df_.TenYearCHD = df_.TenYearCHD.astype('float64')  
df_[['TenYearCHD']] += 0.05*np.random.randn(len(df_), 1)

scatp = df_.plot.scatter(
    x='sysBP',
    y='TenYearCHD',
    sharex=False, 
    colorbar=False,
    alpha=0.2,
    title='Data points and model'
)
y_pred = results.predict(X)
logitp = plt.plot(x, y_pred, 'k--', linewidth=2)

plt.text(220, 0.4, fontsize=12,
         s='NOTE: added random y-offset of points \nfrom their actual values 0/1 \nto visualize density',
         )

# h1, bins = np.histogram(df_[df.TenYearCHD==1], range(90, 260, 10)) 
# h0, bins = np.histogram(df_[df.TenYearCHD==0], range(90, 260, 10)) 
# plt.plot(bins[1:], h1 / (h0+h1), 'kd-', alpha=0.5)
plt.xlim(80, 300)
# Out:
# c:\Users\ronmo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# (80.0, 300.0)

# %%
# lets define a threshold and split to classes
bool_pred = results.predict(X) > 0.5
y_pred = bool_pred.astype(int)
df['logistic 1d prediction'] = y_pred
df['logistic 1d prediction']
# Out:
# 2665    0
# 3578    0
# 420     0
# 2894    0
# 1685    0
#        ..
# 1588    1
# 2091    1
# 864     1
# 3489    1
# 481     1
# Name: logistic 1d prediction, Length: 4238, dtype: int32

# %%
# Create a copy and add noise:
df_ = pd.DataFrame(df[['sysBP','TenYearCHD', 'logistic 1d prediction']])
df_.TenYearCHD = df_.TenYearCHD.astype('float64')  
df_[['TenYearCHD']] += 0.05*np.random.randn(len(df_), 1)

scatp = df_.plot.scatter(
    x='sysBP',
    y='TenYearCHD',
    c='logistic 1d prediction',
    cmap='jet',
    sharex=False, 
    colorbar=False,
    alpha=0.2,
    title='Data points and model (coloring by prediction!)'
)

logitp = plt.plot(x, results.predict(X), 'k:', x, y_pred, 'k--', linewidth=2)
plt.legend(['data', 'prob model', 'decision'])

plt.text(240, 0.4, fontsize=12,
         s='NOTE: added random y-offset of points \nfrom their actual values 0/1 \nto visualize density',
         )
plt.text(180, 0.18, fontsize=12, color='b',
         s='False positives',
         )
plt.text(140, 0.8, fontsize=12, color='r',
         s='False negatives',
         )
# Out:
# Text(140, 0.8, 'False negatives')

# %% [markdown]
# <div dir=rtl>
#     ד. צרו מודל לינארי לניבוי האם נבדק יחלה או לא על בסיס שני פיצ'רים.
# </div>
# <br /><br />
# <div dir=rtl>
#     תחילה נבחר פיצ'רים - על בסיס התרשים למעלה נבחר בלחץ הדם הסיסטואלי כפונקציה של לחץ הדם הדיאסטולי. נשרטט את הנקודות על המישור כדי לבחון את ההתפלגות.
# </div>

# %%
scatp = df[['sysBP','diaBP','TenYearCHD']].plot.scatter(
    x='diaBP',
    y='sysBP',
    c='TenYearCHD',
    cmap='jet',
    sharex=False,
    alpha=0.5,
 
 
)

# %% [markdown]
# <div dir=rtl>
#     במודל דו-מימדי יהיו לנו שני משתנים בלתי תלויים וה"גובה" של הפונקציה (מאפס ועד אחת) יהיה משתנה בפני עצמו:
# </div>
#
# \begin{align}
# \hat{y} = \frac{1}{1+e^{-z}}\\
# z = a_0 + a_1x + a_2y\\
# \end{align}

# %%
logistic_2d = sm.Logit(
    df['TenYearCHD'],
    sm.add_constant(df[['diaBP','sysBP']])
)

results_2d = logistic_2d.fit()
results_2d.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.113214
#          Iterations 9
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:             TenYearCHD   No. Observations:                 4238
# Model:                          Logit   Df Residuals:                     4235
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 20 Apr 2025   Pseudo R-squ.:                  0.7343
# Time:                        22:02:11   Log-Likelihood:                -479.80
# converged:                       True   LL-Null:                       -1805.8
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -9.0277      0.636    -14.184      0.000     -10.275      -7.780
# diaBP         -0.2372      0.012    -19.567      0.000      -0.261      -0.213
# sysBP          0.1760      0.007     24.287      0.000       0.162       0.190
# ==============================================================================
# """

# %% [markdown]
# <div dir=rtl>
#     גם כעת ברצוננו לראות את הישר המפריד בין הנתונים. לצורך כך כתבתי פונקציה. אין צורך להתעכב על כל שורה בה.
# </div>

# %%
import numpy as np
def decision_boundary_plot(df, x, y, results, add_c=True, p=1, level=5):
    xx, yy = np.mgrid[
        df[x].min():df[x].max():level,
        df[y].min():df[y].max():level
    ]
    grid = np.vstack([xx.ravel(), yy.ravel()]).T
    grid = pd.DataFrame(grid, columns = [x,y])**p
    
    if add_c:
        hh = results.predict(sm.add_constant(grid)).values.reshape(xx.shape)
    else:
        hh = results.predict(grid).values.reshape(xx.shape)
            
    return plt.contour(xx,yy,hh, 1)


scatp = df[['sysBP','diaBP','TenYearCHD']].plot.scatter(
    x='diaBP',
    y='sysBP',
    c='TenYearCHD',
    cmap='jet',
    sharex=False,
    alpha=0.5
)

decp = decision_boundary_plot(df, 'diaBP', 'sysBP', results_2d)

# %% [markdown]
# שימו לב, הקו המפריד יכול להפוך למישור במקרה 3-מימדי (3 פיצ"רים) או למרחב 3-מימדי משוכן בתוך מרחב 4-מימדי וכך הלאה.
#
#
# הישר הניצב למישור מפריד זה הוא הישר אליו מבוצעת ההטלה, ולאורכו מתקיים המידול הסיגמואידלי

# %% [markdown]
# <div dir=rtl>
# מה עוד אפשר לעשות?
# </br>
# האם אפשר לעשות רק "ישרים" מפרידים?
# </div>

# %%
from sklearn.datasets import make_circles
import matplotlib.pyplot as plt

data, labels = make_circles(n_samples=1000, noise=0.2, factor=0.2)

plt.figure()
plt.scatter(data[:,0], data[:,1], c=labels, alpha=0.7)

plt.show()

# %%
import statsmodels.api as sm

logistic_2d_circle= sm.Logit(labels,data**2)

results = logistic_2d_circle.fit()
results.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.473036
#          Iterations 7
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1000
# Model:                          Logit   Df Residuals:                      998
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 20 Apr 2025   Pseudo R-squ.:                  0.3176
# Time:                        22:02:13   Log-Likelihood:                -473.04
# converged:                       True   LL-Null:                       -693.15
# Covariance Type:            nonrobust   LLR p-value:                 9.687e-98
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -2.3704      0.296     -8.011      0.000      -2.950      -1.790
# x2            -2.6459      0.322     -8.220      0.000      -3.277      -2.015
# ==============================================================================
# """

# %%
df_circ=pd.DataFrame(data, columns=['x', 'y'])

decision_boundary_plot(df_circ, 'x', 'y', results, add_c=False, p=2, level=0.2)

plt.scatter(data[:,0],data[:,1] ,c=labels, alpha=0.7)

# %% [markdown]
# <div dir=rtl>
# נושאים לדיון המשך:
# </br>
# </br>
# א. השוו זאת למה שעשינו כדי לעשות פיט לא-ליניארי -
# </br>
# בעזרת רגרסיה ליניארית במרחב אחר, של פיצ"רים מחושבים. ממדלים פונקציה לא-ליניארית של X , ע"יקומבינציה ליניארית של פונקציות בסיס של X
# </div>
#
# <div dir=rtl>
# </br>
# בקלסיפיקציה ע"י רגרסיה לוגיסטית על פיצ"רים מחושבים אנחנו מייצרים יריעות שוות-הסתברות צורניות.
# </br>
#  ממדלים פונקציה לוגיסטית שמשתנה לאורך ציר ישר במרחב הפיצ"רים המחושבים,
#  . בניצב לציר זה היפר-מישורים שווי הסתברות, שמיתרגמים ליריעות עקומות במרחב הפיצ"רים המקוריים
#  </br>
#   זה כולל את משטח ההפרדה p=0.5
# </br>
# </div>

# %% [markdown]
# <div dir=rtl>
#
# ב. למה לעצור באליפסה?
# </br>
# לכאורה היינו יכולים להוסיף למודל איברים מסדר ראשון (X, Y),
#  ולקבל דרגות חופש נוספות ועוד גמישות למשטח ההפרדה - ובאופן דומה ערכים מסדר גבוה
# </div>
# </br>
# <div dir=rtl>
#     באופן תאורטי היינו יכולים להתאים כל צורה אך יש סכנת אופברפיט..
#     </br>
#     כדי למנוע מגבילים את כמות הפיצ"רים, עוצרים מוקדם את האימון, או מוסיפים ל-LOSS אברי רגולריזצייה
# </div>
